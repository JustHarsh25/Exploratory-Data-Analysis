# %%
import pandas as pd
import numpy as np

# %%
subjects = ['fcsp-2','fsd-20','toc','coa','dm']
marks = [90,85,80,75,70]
print(pd.Series(marks,index=subjects,name='markes scored'))
# Out:
# fcsp-2    90
# fsd-20    85
# toc       80
# coa       75
# dm        70
# Name: markes scored, dtype: int64

# %%
marks = {'fsd-2':90,'fcsp-2':80,'dm':'70','toc':60,'coa':50}
print(pd.Series(marks))
# Out:
# fsd-2     90
# fcsp-2    80
# dm        70
# toc       60
# coa       50
# dtype: object

# %%
a = np.array([1,2])
ser = pd.Series(a,copy=True)
ser.iloc[0] = 90
print(a)
print(ser)
# Out:
# [1 2]
# 0    90
# 1     2
# dtype: int32

# %%
data = pd.read_csv("imdb_top_1000.csv")

# %%
data
# Out:
#                                            Poster_Link
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime
# 0    The Shawshank Redemption          1994           A  142 min  \
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
series = data['Poster_Link']
series
# Out:
# 0      https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      https://m.media-amazon.com/images/M/MV5BMWU4N2...
#                              ...
# 995    https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    https://m.media-amazon.com/images/M/MV5BMTY5OD...
# Name: Poster_Link, Length: 1000, dtype: object

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.head(10)
# Out:
#                                          Poster_Link
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate
# 0                       The Shawshank Redemption          1994           A  \
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %%
title = data[['Series_Title','Certificate']]
title
# Out:
#                  Series_Title Certificate
# 0    The Shawshank Redemption           A
# 1               The Godfather           A
# 2             The Dark Knight          UA
# 3      The Godfather: Part II           A
# 4                12 Angry Men           U
# ..                        ...         ...
# 995    Breakfast at Tiffany's           A
# 996                     Giant           G
# 997     From Here to Eternity      Passed
# 998                  Lifeboat         NaN
# 999              The 39 Steps         NaN
#
# [1000 rows x 2 columns]

# %%
ce_data = [[100,80,15],[60,70,17],[120,80,14],[80,50,20]]
df = pd.DataFrame(ce_data, columns = ['fcsp-2','dm','fsd-2'])
df
# Out:
#    fcsp-2  dm  fsd-2
# 0     100  80     15
# 1      60  70     17
# 2     120  80     14
# 3      80  50     20

# %%
d = {'name':['A','B','C','D'],
     'id':[100,90,80,70],
     'marks':[80,60,100,90]
    }
df = pd.DataFrame(d)
df.set_index('name', inplace = True)
df
# Out:
#        id  marks
# name
# A     100     80
# B      90     60
# C      80    100
# D      70     90

# %%
print(dir(pd.Series))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ro
# ...

# %%
print(dir(pd.DataFrame))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '
# ...

# %%
movies = pd.read_csv("imdb_top_1000.csv")

# %%
movies.T
# Out:
#                                                              0
# Poster_Link    https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# Series_Title                            The Shawshank Redemption
# Released_Year                                               1994
# Certificate                                                    A
# Runtime                                                  142 min
# Genre                                                      Drama
# IMDB_Rating                                                  9.3
# Overview       Two imprisoned men bond over a number of years...
# Meta_score                                                  80.0
# Director                                          Frank Darabont
# Star1                                                Tim Robbins
# Star2                                             Morgan Freeman
# Star3                                                 Bob Gunton
# ...

# %%
print(movies.at[5,'Overview'])
# Out:
# Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.

# %%
movies.at[2,'IMDB_Rating'] = 9.01
print(movies.at[2,'IMDB_Rating'])
# Out:
# 9.01

# %%
print(movies.axes)
# Out:
# [RangeIndex(start=0, stop=1000, step=1), Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')]

# %%
print(movies.columns)
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
print(movies['Released_Year'].unique())
# Out:
# ['1994' '1972' '2008' '1974' '1957' '2003' '1993' '2010' '1999' '2001'
#  '1966' '2002' '1990' '1980' '1975' '2020' '2019' '2014' '1998' '1997'
#  '1995' '1991' '1977' '1962' '1954' '1946' '2011' '2006' '2000' '1988'
#  '1985' '1968' '1960' '1942' '1936' '1931' '2018' '2017' '2016' '2012'
#  '2009' '2007' '1984' '1981' '1979' '1971' '1963' '1964' '1950' '1940'
#  '2013' '2005' '2004' '1992' '1987' '1986' '1983' '1976' '1973' '1965'
#  '1959' '1958' '1952' '1948' '1944' '1941' '1927' '1921' '2015' '1996'
#  '1989' '1978' '1961' '1955' '1953' '1925' '1924' '1982' '1967' '1951'
#  '1949' '1939' '1937' '1934' '1928' '1926' '1920' '1970' '1969' '1956'
#  '1947' '1945' '1930' '1938' '1935' '1933' '1932' '1922' '1943' 'PG']

# %%
df = pd.DataFrame({'A':[np.nan]})
print(df)
# Out:
#     A
# 0 NaN

# %%
movies.iloc[[0,2],[1,3]]
# Out:
#                Series_Title Certificate
# 0  The Shawshank Redemption           A
# 2           The Dark Knight          UA

# %%
print(type(movies.iloc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(movies.iloc[[0]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
movies.iloc[0,7]
# Out:
# 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'

# %%
movies.iloc[[0,7]]
# Out:
#                                          Poster_Link
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
#
#                Series_Title Released_Year Certificate  Runtime
# 0  The Shawshank Redemption          1994           A  142 min  \
# 7          Schindler's List          1993           A  195 min
#
#                        Genre  IMDB_Rating
# 0                      Drama          9.3  \
# 7  Biography, Drama, History          8.9
#
#                                             Overview  Meta_score
# 0  Two imprisoned men bond over a number of years...        80.0  \
# 7  In German-occupied Poland during World War II,...        94.0
#
#            Director        Star1           Star2         Star3
# 0    Frank Darabont  Tim Robbins  Morgan Freeman    Bob Gunton  \
# 7  Steven Spielberg  Liam Neeson   Ralph Fiennes  Ben Kingsley
#
#               Star4  No_of_Votes       Gross
# ...

# %%
movies.iloc[:5]
# Out:
#                                          Poster_Link
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime
# 0  The Shawshank Redemption          1994           A  142 min  \
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating
# 0                 Drama         9.30  \
# 1          Crime, Drama         9.20
# 2  Action, Crime, Drama         9.01
# 3          Crime, Drama         9.00
# 4          Crime, Drama         9.00
#
# ...

# %%
df = pd.DataFrame([[0,2,3],[0,4,1],[10,20,30],[1,2,3]], index = ['Q','W','E','R'] ,columns = ['A','B','C'])
df
# Out:
#     A   B   C
# Q   0   2   3
# W   0   4   1
# E  10  20  30
# R   1   2   3

# %%
df.iloc[1]
# Out:
# A    0
# B    4
# C    1
# Name: W, dtype: int64

# %%
df.iloc[[True,False,True,False]]
# Out:
#     A   B   C
# Q   0   2   3
# E  10  20  30

# %%
df.loc['W':'R','C']
# Out:
# W     1
# E    30
# R     3
# Name: C, dtype: int64

# %%
movies.iloc[lambda x:x.index%2==0]
# Out:
#                                            Poster_Link
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
#
#                  Series_Title Released_Year Certificate  Runtime
# 0    The Shawshank Redemption          1994           A  142 min  \
# 2             The Dark Knight          2008          UA  152 min
# 4                12 Angry Men          1957           U   96 min
# ...

# %%
movies.iloc[0,1]
# Out:
# 'The Shawshank Redemption'

# %%
movies.iloc[1:4,0:6]
# Out:
#                                          Poster_Link            Series_Title
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...           The Godfather  \
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...         The Dark Knight
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...  The Godfather: Part II
#
#   Released_Year Certificate  Runtime                 Genre
# 1          1972           A  175 min          Crime, Drama
# 2          2008          UA  152 min  Action, Crime, Drama
# 3          1974           A  202 min          Crime, Drama

# %%
for i in range(len(movies)):
    print(movies.at[i,'Poster_Link'],movies.at[i,'Series_Title'])
# Out:
# https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg The Shawshank Redemption
# https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg The Godfather
# https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg The Dark Knight
# https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg The Godfather: Part II
# https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg 12 Angry Men
# https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg The Lord of the Rings: The Return of the King
# ...

# %%
movies.iloc[0:100:10,:10]
# Out:
#                                           Poster_Link
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 20  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 30  https://m.media-amazon.com/images/M/MV5BYjBmYT...
# 40  https://m.media-amazon.com/images/M/MV5BZjA0MT...
# 50  https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 60  https://m.media-amazon.com/images/M/MV5BMjMxNj...
# 70  https://m.media-amazon.com/images/M/MV5BNGIzY2...
# 80  https://m.media-amazon.com/images/M/MV5BNjViMm...
# 90  https://m.media-amazon.com/images/M/MV5BMWE3MG...
#
#                                          Series_Title Released_Year
# 0                            The Shawshank Redemption          1994  \
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 20                                    Soorarai Pottru          2020
# 30                                            Seppuku          1962
# ...

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)
